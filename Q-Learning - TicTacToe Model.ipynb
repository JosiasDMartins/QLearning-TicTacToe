# %%
from Jogo import JogoDaVelha, play_game

# %%
import random
import numpy as np

class QLearningAgent:
    def __init__(self, epsilon=0.1, gamma=0.9, learning_rate=0.1):
        self.q_table = {}
        self.epsilon = epsilon
        self.gamma = gamma
        self.learning_rate = learning_rate

    def get_state_key(self, state):
        return tuple(map(tuple, state))

    def choose_action(self, state):
        state_key = self.get_state_key(state)
        if state_key not in self.q_table:
            self.q_table[state_key] = [0] * 9

        valid_moves = [i for i in range(9) if state[i // 3][i % 3] == 0]
        if not valid_moves:
            return random.choice(range(9))
            
        if random.random() < self.epsilon:
            return random.choice(valid_moves)
        else:
            q_values = [self.q_table[state_key][i] for i in valid_moves]
            max_q = max(q_values)
            best_options = [i for i, q in zip(valid_moves, q_values) if q ==max_q]
            return random.choice(best_options)

    def learn(self, state, action, reward, next_state):
        state_key = self.get_state_key(state)
        next_state_key = self.get_state_key(next_state)

        if state_key not in self.q_table:
            self.q_table[state_key] = [0] * 9
            
        if next_state_key not in self.q_table:
            self.q_table[next_state_key] = [0] * 9

        max_next_q = max(self.q_table[next_state_key])
        current_q = self.q_table[state_key][action]
        self.q_table[state_key][action] = current_q + self.learning_rate*(reward + self.gamma*max_next_q - current_q)

# %%
agent = QLearningAgent()

# %%
import numpy as np
import random
from tqdm import tqdm

num_episodes = 1000

for episode in tqdm(range(num_episodes), desc="Treinando"):
    game = JogoDaVelha()
    while not game.game_over:

        state = game.board
        action = agent.choose_action(state)
        game.make_move(action // 3, action % 3)

        next_state = game.board

        if game.winner == 1:
            reward = 1
        elif game.winner == 0:
            reward =0
        else:
            reward = -1

        agent.learn(state, action, reward, next_state)
# Out:
# Treinando: 100%|██████████| 1000/1000 [00:00<00:00, 2493.34it/s]

# %% [raw]
# play_game(agent)

# %%
import numpy as np
import random
from tqdm import tqdm

num_episodes = 1000000

for episode in tqdm(range(num_episodes), desc="Treinando"):
    game = JogoDaVelha()

    if episode % 2 == 0:
        game.current_player = 1
    else:
        game.current_player = -1
    
    while not game.game_over:

        state = game.board.copy()
        if game.current_player == -1:
            action = agent.choose_action(state)
            game.make_move(action // 3, action % 3)
        else:
            valid_moves = [i for i in range(9) if game.board[i // 3][i % 3] == 0]
            action = random.choice(valid_moves)
            game.make_move(action // 3, action % 3)

        next_state = game.board.copy()
        if game.game_over:
            if game.winner == -1:
                reward = 1
            elif game.winner == 1:
                reward =-1
            else:
                reward = 0
        else:
            reward = 0

        agent.learn(state, action, reward, next_state)
# Out:
# Treinando: 100%|██████████| 1000000/1000000 [05:53<00:00, 2826.91it/s]

# %%
def print_q_table(q_table):
    for state, q_values in q_table.items():
        print(f"State: {state}")
        for action, q_value in enumerate(q_values):
            print(f"Action {action}: Q = {q_value}")
        print("-------")

print_q_table(agent.q_table)
# Out:
# State: ((0, 0, 0), (0, 0, 0), (0, 0, 0))
# Action 0: Q = 0.592395004966719
# Action 1: Q = 0.6469519752921151
# Action 2: Q = 0.6164105766727532
# Action 3: Q = 0.6428111283528557
# Action 4: Q = 0.6108443041410916
# Action 5: Q = 0.637786150404426
# Action 6: Q = 0.6364048584684455
# Action 7: Q = 0.6185245884592753
# Action 8: Q = 0.6400248039602144
# -------
# State: ((1, 0, 0), (0, 0, 0), (0, 0, 0))
# Action 0: Q = -0.9999825730661898
# Action 1: Q = 0.6015159177276557
# Action 2: Q = 0.657944060500502
# Action 3: Q = 0.654270085019772
# Action 4: Q = 0.6551489767843166
# Action 5: Q = 0.6569572298479467
# Action 6: Q = 0.656976792431962
# Action 7: Q = 0.6543952677687875
# Action 8: Q = 0.642074744553349
# -------
# State: ((1, 0, 0), (-1, 0, 0), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0.6667374417659079
# Action 2: Q = 0.6652936675739731
# Action 3: Q = -0.814697981114816
# Action 4: Q = 0.5903068331250887
# Action 5: Q = 0.7524832385168309
# Action 6: Q = 0.6800274179831922
# Action 7: Q = 0.6752297736563324
# Action 8: Q = 0.6841909377533392
# -------
# State: ((1, 0, 0), (-1, 0, 0), (1, 0, 0))
# Action 0: Q = -0.34390000000000004
# Action 1: Q = 0.494338197718709
# Action 2: Q = 0.5340300878786758
# Action 3: Q = 0
# Action 4: Q = 0.8043689515393683
# Action 5: Q = 0.8491745682580345
# Action 6: Q = -0.19
# Action 7: Q = 0.5538041115042552
# Action 8: Q = 0.6370762144192389
# -------
# State: ((1, 0, 0), (-1, 0, -1), (1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0.8826503376498388
# Action 2: Q = 0.86822172342141
# Action 3: Q = -0.1
# Action 4: Q = 0.9540956026220708
# Action 5: Q = -0.19
# Action 6: Q = 0
# Action 7: Q = 0.8323961903439612
# Action 8: Q = 0.8765812151751806
# -------
# State: ((1, 0, 1), (-1, 0, -1), (1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0.6753810722182562
# Action 2: Q = -0.1
# Action 3: Q = 0
# Action 4: Q = 0.9999999999999996
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.7425139834596721
# Action 8: Q = 0.6960934235783061
# -------
# State: ((1, -1, 1), (-1, 0, -1), (1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = -0.10302619202512338
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.7661999007928045
# Action 8: Q = 0.600158793567121
# -------
# State: ((1, -1, 1), (-1, 0, -1), (1, 0, 1))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.40951000000000004
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.8142668342968961
# Action 8: Q = -0.1
# -------
# State: ((1, -1, 1), (-1, 0, -1), (1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = -0.1
# Action 4: Q = 0.9558957359347124
# Action 5: Q = -0.1
# Action 6: Q = 0
# Action 7: Q = -0.1
# Action 8: Q = 0
# -------
# State: ((1, -1, 1), (-1, 1, -1), (1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.29701
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (0, 0, 0), (1, 0, 0))
# Action 0: Q = 0.6598009448438104
# Action 1: Q = 0.7125279666916214
# Action 2: Q = 0.6751690826331741
# Action 3: Q = 0.670332016679063
# Action 4: Q = 0.6795984611841214
# Action 5: Q = 0.6779978749695896
# Action 6: Q = -0.9999885661887271
# Action 7: Q = 0.6744383010288352
# Action 8: Q = 0.6731170420564497
# -------
# State: ((0, 0, 0), (0, 0, -1), (1, 0, 0))
# Action 0: Q = 0.7288358032087705
# Action 1: Q = 0.7203152871119356
# Action 2: Q = 0.7286614044332038
# Action 3: Q = 0.7646201343849279
# Action 4: Q = 0.7289999999168382
# Action 5: Q = -0.814697981114816
# Action 6: Q = 0
# Action 7: Q = 0.7178340386871134
# Action 8: Q = 0.7284609222889751
# -------
# State: ((0, 0, 0), (0, 1, -1), (1, 0, 0))
# Action 0: Q = 0.5420999245519676
# Action 1: Q = 0.3981039486851195
# Action 2: Q = 0.8099999999998
# Action 3: Q = 0.612213885882884
# Action 4: Q = -0.19
# Action 5: Q = 0
# Action 6: Q = -0.19
# Action 7: Q = 0.437333488061307
# Action 8: Q = 0.6815826580382313
# -------
# State: ((0, 0, -1), (0, 1, -1), (1, 0, 0))
# Action 0: Q = 0.8999984064351174
# Action 1: Q = 0.8999700907239527
# Action 2: Q = -0.19
# Action 3: Q = 0.8999999999991839
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.8999999999999247
# Action 8: Q = 0.7183048070132173
# -------
# State: ((0, 0, -1), (0, 1, -1), (1, 0, 1))
# Action 0: Q = 0.7792841480261576
# Action 1: Q = 0.12480815902075118
# Action 2: Q = 0
# Action 3: Q = 0.0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.194637456991977
# Action 8: Q = -0.1
# -------
# State: ((0, 0, -1), (0, 1, -1), (1, -1, 1))
# Action 0: Q = -0.6884552252398752
# Action 1: Q = 0.04924312438947531
# Action 2: Q = 0
# Action 3: Q = 0.13669668545105196
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = -0.1
# Action 8: Q = 0
# -------
# State: ((0, 1, -1), (0, 1, -1), (1, -1, 1))
# Action 0: Q = 0.0
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0.0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 1, -1), (-1, 1, -1), (1, -1, 1))
# Action 0: Q = -0.5643959923831233
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = -0.19
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, -1), (-1, 1, -1), (1, -1, 1))
# Action 0: Q = 0.199
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.11791000000000001
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.11791000000000001
# -------
# State: ((0, 1, 0), (0, 0, 0), (0, 0, 0))
# Action 0: Q = 0.6429416491660441
# Action 1: Q = -0.9999964119488688
# Action 2: Q = 0.6676447492288661
# Action 3: Q = 0.6704725145494543
# Action 4: Q = 0.6514745481766538
# Action 5: Q = 0.6479433080057999
# Action 6: Q = 0.667997183434512
# Action 7: Q = 0.6649958846140203
# Action 8: Q = 0.6441987195328848
# -------
# State: ((0, 1, 0), (0, -1, 0), (0, 0, 0))
# Action 0: Q = 0.7230290964059012
# Action 1: Q = 0
# Action 2: Q = 0.7211407953506794
# Action 3: Q = 0.7222647226132024
# Action 4: Q = -0.8332281830033343
# Action 5: Q = 0.7227819618808539
# Action 6: Q = 0.722993129621137
# Action 7: Q = 0.7149594124918315
# Action 8: Q = 0.7223159157823377
# -------
# State: ((0, 1, 0), (1, -1, 0), (0, 0, 0))
# Action 0: Q = 0.7322222600605914
# Action 1: Q = -0.19
# Action 2: Q = 0.7848647237774531
# Action 3: Q = -0.271
# Action 4: Q = 0
# Action 5: Q = 0.7011360499100286
# Action 6: Q = 0.8063039120181896
# Action 7: Q = 0.7189646675659241
# Action 8: Q = 0.7429533244896595
# -------
# State: ((0, 1, -1), (1, -1, 0), (0, 0, 0))
# Action 0: Q = 0.7611911899917417
# Action 1: Q = 0
# Action 2: Q = -0.1
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0.852230115724874
# Action 6: Q = 0.819361473327712
# Action 7: Q = 0.8418214196954552
# Action 8: Q = 0.8415140080725472
# -------
# State: ((0, 1, -1), (1, -1, 1), (0, 0, 0))
# Action 0: Q = 0.7463531238810203
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.1
# Action 6: Q = 0.9999999999999996
# Action 7: Q = 0.5965565828590006
# Action 8: Q = 0.7263177836576572
# -------
# State: ((0, 1, -1), (1, -1, 1), (0, 0, -1))
# Action 0: Q = 0.9957507407216594
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.7441273181443666
# Action 7: Q = 0.6240933547729953
# Action 8: Q = -0.19
# -------
# State: ((0, 1, -1), (1, -1, 1), (1, 0, -1))
# Action 0: Q = 0.9999999999999958
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0.15883255510848995
# Action 8: Q = 0
# -------
# State: ((-1, 1, -1), (1, -1, 1), (1, 0, -1))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (0, 0, 0), (0, 0, 1))
# Action 0: Q = 0.6529598680308915
# Action 1: Q = 0.7148505879720192
# Action 2: Q = 0.6682191784153908
# Action 3: Q = 0.6697401446382628
# Action 4: Q = 0.6726369694413912
# Action 5: Q = 0.6027586127433174
# Action 6: Q = 0.6734555985711508
# Action 7: Q = 0.6551749293840897
# Action 8: Q = -0.9999825730661898
# -------
# State: ((0, 0, 0), (0, 0, 0), (0, -1, 1))
# Action 0: Q = 0.6608315287210653
# Action 1: Q = 0.6332132112628718
# Action 2: Q = 0.6560506575884798
# Action 3: Q = 0.6803264181999076
# Action 4: Q = 0.6899517026078487
# Action 5: Q = 0.696730468077104
# Action 6: Q = 0.6550630967187021
# Action 7: Q = -0.814697981114816
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (0, 0, 0), (1, -1, 1))
# Action 0: Q = 0.46637705317185746
# Action 1: Q = 0.7766119823325421
# Action 2: Q = 0.5329696564926067
# Action 3: Q = 0.5420588736757208
# Action 4: Q = 0.7539289261877892
# Action 5: Q = 0.6738373779272019
# Action 6: Q = -0.40951000000000004
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 0, 0), (0, 0, 0), (1, -1, 1))
# Action 0: Q = -0.1
# Action 1: Q = 0.11085412280117789
# Action 2: Q = 0.7186234605873026
# Action 3: Q = 0.4956341846618996
# Action 4: Q = 0.508544284136134
# Action 5: Q = 0.21018669629980333
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 0, 0), (1, 0, 0), (1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0.8895385167367292
# Action 2: Q = 0.006305601088262405
# Action 3: Q = -0.1
# Action 4: Q = 0.16399024248491467
# Action 5: Q = 0.08014201808530218
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 0), (1, 0, 0), (1, -1, 1))
# Action 0: Q = -0.1
# Action 1: Q = -0.19
# Action 2: Q = 0.9950940226312953
# Action 3: Q = 0
# Action 4: Q = 0.9248341841667248
# Action 5: Q = 0.8144972375960069
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 0), (1, 1, 0), (1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.9999999999999996
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0.16881891669007648
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, -1, -1), (1, 1, 0), (1, -1, 1))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = -0.1
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (1, 0, 0), (0, 0, 0))
# Action 0: Q = 0.6641331844392184
# Action 1: Q = 0.7189681021095462
# Action 2: Q = 0.6843648202047498
# Action 3: Q = -0.9999500200419471
# Action 4: Q = 0.6472752457711296
# Action 5: Q = 0.6337578725908896
# Action 6: Q = 0.6802611544333315
# Action 7: Q = 0.6875364168318693
# Action 8: Q = 0.6882844586160828
# -------
# State: ((0, 0, 0), (1, -1, 0), (0, 0, 0))
# Action 0: Q = 0.7205304091101129
# Action 1: Q = 0.7183039406830912
# Action 2: Q = 0.7118666034581443
# Action 3: Q = 0
# Action 4: Q = -0.8649148282327008
# Action 5: Q = 0.7163821914268527
# Action 6: Q = 0.7184267624778612
# Action 7: Q = 0.7192133473485007
# Action 8: Q = 0.719433596443009
# -------
# State: ((0, 0, 0), (1, -1, 1), (0, 0, 0))
# Action 0: Q = 0.8059858048374156
# Action 1: Q = 0.6542877838376193
# Action 2: Q = 0.7586916781319928
# Action 3: Q = -0.19
# Action 4: Q = 0
# Action 5: Q = -0.40951000000000004
# Action 6: Q = 0.7702352679329147
# Action 7: Q = 0.7584530005080424
# Action 8: Q = 0.7412544811528525
# -------
# State: ((0, -1, 0), (1, -1, 1), (0, 0, 0))
# Action 0: Q = 0.5510697438247003
# Action 1: Q = -0.1
# Action 2: Q = 0.6603989511440811
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.6943787947276188
# Action 7: Q = 0.6686801754375093
# Action 8: Q = 0.7486537004320353
# -------
# State: ((0, -1, 1), (1, -1, 1), (0, 0, 0))
# Action 0: Q = 0.00951938686914668
# Action 1: Q = 0
# Action 2: Q = -0.1
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.023604990639290196
# Action 7: Q = 0.271
# Action 8: Q = 0.856265238233557
# -------
# State: ((0, -1, 1), (1, -1, 1), (0, 0, -1))
# Action 0: Q = 0.6725059579417442
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.8487230854647343
# Action 7: Q = 0.9512832816203132
# Action 8: Q = -0.1
# -------
# State: ((0, -1, 1), (1, -1, 1), (0, 1, -1))
# Action 0: Q = 0.9999999999999849
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.39193866035894864
# Action 7: Q = -0.1
# Action 8: Q = 0
# -------
# State: ((0, -1, 1), (1, -1, 1), (-1, 1, -1))
# Action 0: Q = 0.9875304505281909
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, 1), (1, -1, 1), (-1, 1, -1))
# Action 0: Q = -0.19
# Action 1: Q = 0
# Action 2: Q = -0.271
# Action 3: Q = -0.19
# Action 4: Q = 0
# Action 5: Q = -0.1
# Action 6: Q = 0
# Action 7: Q = -0.1
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (0, 0, 1), (0, 0, 0))
# Action 0: Q = 0.6511260113554327
# Action 1: Q = 0.7232209454368154
# Action 2: Q = 0.6943547512097346
# Action 3: Q = 0.6953300559527965
# Action 4: Q = 0.6838549390117814
# Action 5: Q = -0.9999984554616402
# Action 6: Q = 0.6789141067873778
# Action 7: Q = 0.6930434927454474
# Action 8: Q = 0.6934833105441041
# -------
# State: ((0, 0, 0), (0, 0, 1), (0, 0, -1))
# Action 0: Q = 0.6741917349470813
# Action 1: Q = 0.7207324244529383
# Action 2: Q = 0.7209246419301099
# Action 3: Q = 0.7266528589281117
# Action 4: Q = 0.7280014674202816
# Action 5: Q = 0
# Action 6: Q = 0.7186994471865015
# Action 7: Q = 0.7813422212290051
# Action 8: Q = -0.814697981114816
# -------
# State: ((0, 0, 0), (0, 1, 1), (0, 0, -1))
# Action 0: Q = 0.5411666800099324
# Action 1: Q = 0.538108167802905
# Action 2: Q = 0.6019567063085207
# Action 3: Q = 0.6364710390772937
# Action 4: Q = -0.19
# Action 5: Q = -0.19
# Action 6: Q = 0.8099940118301722
# Action 7: Q = 0.7306849671067465
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (-1, 1, 1), (0, 0, -1))
# Action 0: Q = 0.6599712135498559
# Action 1: Q = 0.4178758155926732
# Action 2: Q = 0.5866705093678889
# Action 3: Q = -0.1
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.31615350374151163
# Action 7: Q = 0.6377684657018796
# Action 8: Q = -0.19
# -------
# State: ((0, 0, 0), (-1, 1, 1), (1, 0, -1))
# Action 0: Q = 0.11878972593141206
# Action 1: Q = 0.013879762249311832
# Action 2: Q = 0.06967634796679309
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0.0
# Action 8: Q = 0
# -------
# State: ((0, 0, -1), (-1, 1, 1), (1, 0, -1))
# Action 0: Q = 0.2820312066297982
# Action 1: Q = 0.015572338945882242
# Action 2: Q = -0.1
# Action 3: Q = -0.1
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.06631469801706204
# Action 8: Q = 0
# -------
# State: ((0, 1, -1), (-1, 1, 1), (1, 0, -1))
# Action 0: Q = 0.0
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.271
# Action 6: Q = 0
# Action 7: Q = 0.0
# Action 8: Q = 0
# -------
# State: ((0, 1, -1), (-1, 1, 1), (1, -1, -1))
# Action 0: Q = 0.0
# Action 1: Q = 0
# Action 2: Q = -0.1
# Action 3: Q = -0.1
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = -0.271
# Action 8: Q = -0.1
# -------
# State: ((1, 1, -1), (-1, 1, 1), (1, -1, -1))
# Action 0: Q = -0.46855900000000006
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, -1), (0, 0, 1), (0, 0, 0))
# Action 0: Q = 0.7215511002824412
# Action 1: Q = 0.7804912515829556
# Action 2: Q = -0.8499053647030009
# Action 3: Q = 0.7265538603091538
# Action 4: Q = 0.7276501083974439
# Action 5: Q = 0
# Action 6: Q = 0.7285088665285875
# Action 7: Q = 0.7283961076135528
# Action 8: Q = 0.7278942566573956
# -------
# State: ((0, 1, -1), (0, 0, 1), (0, 0, 0))
# Action 0: Q = 0.6359569919506673
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0.6710027899144516
# Action 4: Q = 0.7942856080530458
# Action 5: Q = -0.19
# Action 6: Q = 0.8092306000863153
# Action 7: Q = 0.5048203243492918
# Action 8: Q = 0.5945325035143458
# -------
# State: ((0, 1, -1), (0, 0, 1), (-1, 0, 0))
# Action 0: Q = 0.7033531606869462
# Action 1: Q = 0
# Action 2: Q = -0.19
# Action 3: Q = 0.7772911862766827
# Action 4: Q = 0.4614885617338679
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0.8997572920505608
# Action 8: Q = 0.7448690863153291
# -------
# State: ((0, 1, -1), (0, 1, 1), (-1, 0, 0))
# Action 0: Q = 0.05886803929823581
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.44343695724183313
# Action 4: Q = -0.1
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.3057403625003589
# Action 8: Q = 0.11703373880859154
# -------
# State: ((0, 1, -1), (0, 1, 1), (-1, 0, -1))
# Action 0: Q = 0.1365268771125617
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = -0.7175810051208186
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = -0.922011380935139
# Action 8: Q = -0.1
# -------
# State: ((0, 1, -1), (1, 1, 1), (-1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.1
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (0, 1, 0), (0, 0, 0))
# Action 0: Q = 0.6474485490508702
# Action 1: Q = 0.6801550319041672
# Action 2: Q = 0.6619158038043222
# Action 3: Q = 0.6490062789422586
# Action 4: Q = -0.9999950781191616
# Action 5: Q = 0.5959595031597533
# Action 6: Q = 0.6619373569303877
# Action 7: Q = 0.5944327747550707
# Action 8: Q = 0.6332632755197525
# -------
# State: ((0, 0, -1), (0, 1, 0), (0, 0, 0))
# Action 0: Q = 0.7289955818630083
# Action 1: Q = 0.7312323693559777
# Action 2: Q = -0.8499053647030009
# Action 3: Q = 0.7192784004596317
# Action 4: Q = 0
# Action 5: Q = 0.7278737316672671
# Action 6: Q = 0.7230020175356493
# Action 7: Q = 0.7289729927703681
# Action 8: Q = 0.7286708145185667
# -------
# State: ((1, 0, -1), (0, 1, 0), (0, 0, 0))
# Action 0: Q = -0.271
# Action 1: Q = 0.49913132920141967
# Action 2: Q = 0
# Action 3: Q = 0.47285301971615584
# Action 4: Q = -0.1
# Action 5: Q = 0.809999999999998
# Action 6: Q = 0.6393243383627454
# Action 7: Q = 0.620209802972598
# Action 8: Q = 0.7301851376575911
# -------
# State: ((1, -1, -1), (0, 1, 0), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0.37733770017978374
# Action 4: Q = 0
# Action 5: Q = 0.7928954646151777
# Action 6: Q = 0.26133321388878944
# Action 7: Q = 0.3209176504799035
# Action 8: Q = 0.01343195810650738
# -------
# State: ((1, -1, -1), (1, 1, 0), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = -0.1
# Action 4: Q = 0
# Action 5: Q = 0.18948397618636564
# Action 6: Q = 0.02732564984408207
# Action 7: Q = 0.0
# Action 8: Q = 0.166621055045244
# -------
# State: ((1, -1, -1), (1, 1, -1), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.1
# Action 6: Q = -0.4488300285710357
# Action 7: Q = 0.05858162269439312
# Action 8: Q = -0.613754376913808
# -------
# State: ((1, -1, -1), (1, 1, -1), (1, 0, 0))
# Action 0: Q = 0.20791000000000004
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.1
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (0, 0, 1), (-1, 0, 0))
# Action 0: Q = 0.7027506944943448
# Action 1: Q = 0.7178978200654739
# Action 2: Q = 0.71907242258375
# Action 3: Q = 0.7278558404926815
# Action 4: Q = 0.72760852230961
# Action 5: Q = 0
# Action 6: Q = -0.717570463519
# Action 7: Q = 0.7476784177060503
# Action 8: Q = 0.7354596312806311
# -------
# State: ((0, 0, 0), (0, 0, 1), (-1, 0, 1))
# Action 0: Q = 0.8096927759106561
# Action 1: Q = 0.689348708082631
# Action 2: Q = 0.8453934832679089
# Action 3: Q = 0.7948404742406616
# Action 4: Q = 0.7133806948891064
# Action 5: Q = -0.1
# Action 6: Q = 0
# Action 7: Q = 0.6770097622727793
# Action 8: Q = -0.19
# -------
# State: ((0, 0, 0), (0, 0, 1), (-1, -1, 1))
# Action 0: Q = 0.6669475201782096
# Action 1: Q = 0.7438692448433071
# Action 2: Q = -0.5307916541111618
# Action 3: Q = 0.7412681173382125
# Action 4: Q = 0.5032561460297096
# Action 5: Q = 0
# Action 6: Q = -0.19
# Action 7: Q = -0.1
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (1, 0, 1), (-1, -1, 1))
# Action 0: Q = 0.021311912435338844
# Action 1: Q = 0.48252690152606414
# Action 2: Q = 0.419592466034669
# Action 3: Q = -0.1
# Action 4: Q = 0.8708045195180986
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (1, -1, 1), (-1, -1, 1))
# Action 0: Q = 0.8512521445156002
# Action 1: Q = 0.9785157571379619
# Action 2: Q = -0.6562731172415257
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 1, 0), (1, -1, 1), (-1, -1, 1))
# Action 0: Q = 0.4364099824288204
# Action 1: Q = -0.1
# Action 2: Q = 0.9999999999999996
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.19
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (1, -1, 1), (-1, -1, 1))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = 0.4454259357500268
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.19
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 1), (1, -1, 1), (-1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.29701
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.24078871000000002
# -------
# State: ((0, 0, 0), (0, -1, 1), (0, 0, 0))
# Action 0: Q = 0.7158593621174715
# Action 1: Q = 0.7163831948635624
# Action 2: Q = 0.7054081775858548
# Action 3: Q = 0.7281286368132394
# Action 4: Q = -0.814697981114816
# Action 5: Q = 0
# Action 6: Q = 0.7253643286336698
# Action 7: Q = 0.7609984474779776
# Action 8: Q = 0.7225728856430972
# -------
# State: ((0, 0, 0), (0, -1, 1), (0, 1, 0))
# Action 0: Q = 0.7766935607100476
# Action 1: Q = 0.6046147392928637
# Action 2: Q = 0.7645831011807364
# Action 3: Q = 0.7162971822639929
# Action 4: Q = 0
# Action 5: Q = -0.1
# Action 6: Q = 0.8094196859219666
# Action 7: Q = -0.34390000000000004
# Action 8: Q = 0.7894028827102143
# -------
# State: ((0, 0, -1), (0, -1, 1), (0, 1, 0))
# Action 0: Q = 0.8103187963889323
# Action 1: Q = 0.7764879754822707
# Action 2: Q = -0.34390000000000004
# Action 3: Q = 0.8082985686945456
# Action 4: Q = -0.19
# Action 5: Q = 0
# Action 6: Q = 0.7079197549844561
# Action 7: Q = 0
# Action 8: Q = 0.7819670648569498
# -------
# State: ((0, 0, -1), (0, -1, 1), (0, 1, 1))
# Action 0: Q = 0.8495210682759367
# Action 1: Q = 0.7000795627699887
# Action 2: Q = 0
# Action 3: Q = 0.6824397152093188
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.9852191170585654
# Action 7: Q = 0
# Action 8: Q = -0.19
# -------
# State: ((0, 0, -1), (-1, -1, 1), (0, 1, 1))
# Action 0: Q = 0.8588840341907689
# Action 1: Q = 0.8865481128265922
# Action 2: Q = 0
# Action 3: Q = -0.19
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.8354140592729211
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 0, -1), (-1, -1, 1), (0, 1, 1))
# Action 0: Q = -0.19
# Action 1: Q = 0.15989867559330045
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.9999999999999996
# Action 7: Q = -0.1
# Action 8: Q = 0
# -------
# State: ((1, 0, -1), (-1, -1, 1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.19
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (0, 0, 0), (0, 1, 0))
# Action 0: Q = 0.6495895514556136
# Action 1: Q = 0.5910000026594384
# Action 2: Q = 0.6739671606387462
# Action 3: Q = 0.6780429881960015
# Action 4: Q = 0.6640708171780881
# Action 5: Q = 0.6440698562141363
# Action 6: Q = 0.6751555276337956
# Action 7: Q = -0.9999939236039033
# Action 8: Q = 0.6750080119053286
# -------
# State: ((0, 0, 0), (0, 0, 0), (0, 1, -1))
# Action 0: Q = 0.7272643650248923
# Action 1: Q = 0.7283265046748844
# Action 2: Q = 0.754153454148896
# Action 3: Q = 0.7288204786668141
# Action 4: Q = 0.6842039501725926
# Action 5: Q = 0.7281647127750371
# Action 6: Q = 0.7285405436742197
# Action 7: Q = 0
# Action 8: Q = -0.7712320754503901
# -------
# State: ((0, 1, 0), (0, 0, 0), (0, 1, -1))
# Action 0: Q = 0.7303972021690481
# Action 1: Q = -0.19
# Action 2: Q = 0.7825368723886598
# Action 3: Q = 0.7110780507823758
# Action 4: Q = 0.8098883361439208
# Action 5: Q = 0.7535073369785436
# Action 6: Q = 0.7028960152346415
# Action 7: Q = -0.34390000000000004
# Action 8: Q = 0
# -------
# State: ((0, 1, 0), (0, -1, 0), (0, 1, -1))
# Action 0: Q = 0.7561691183070698
# Action 1: Q = 0
# Action 2: Q = 0.8997153259830825
# Action 3: Q = 0.8998729014392425
# Action 4: Q = -0.1
# Action 5: Q = 0.8999060629506072
# Action 6: Q = 0.8998043757428736
# Action 7: Q = 0
# Action 8: Q = -0.1
# -------
# State: ((1, 1, 0), (0, -1, 0), (0, 1, -1))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = 0.7696124776431508
# Action 3: Q = 0.78515315087075
# Action 4: Q = 0
# Action 5: Q = 0.8314734386887955
# Action 6: Q = 0.6836212572616388
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, 0), (0, -1, 0), (-1, 1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = -0.738090232893543
# Action 3: Q = 0.8081403375050691
# Action 4: Q = 0
# Action 5: Q = 0.8630663961576672
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, 1), (0, -1, 0), (-1, 1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.1
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 0, 0), (0, -1, 0), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0.7157214766923661
# Action 2: Q = 0.7212554856584579
# Action 3: Q = 0.7275080820305542
# Action 4: Q = -0.8332281830033343
# Action 5: Q = 0.722484716309894
# Action 6: Q = 0.7243562319879037
# Action 7: Q = 0.7123865308760045
# Action 8: Q = 0.7224063016238204
# -------
# State: ((1, 0, 1), (0, -1, 0), (0, 0, 0))
# Action 0: Q = -0.40951000000000004
# Action 1: Q = 0.6520764054436187
# Action 2: Q = -0.40951000000000004
# Action 3: Q = 0.7498016267214972
# Action 4: Q = 0
# Action 5: Q = 0.7481402754212803
# Action 6: Q = 0.675174845090786
# Action 7: Q = 0.7912693483318747
# Action 8: Q = 0.6812967191683774
# -------
# State: ((1, 0, 1), (0, -1, 0), (0, -1, 0))
# Action 0: Q = 0
# Action 1: Q = -0.9999981165341321
# Action 2: Q = 0
# Action 3: Q = 0.8765706108635235
# Action 4: Q = 0
# Action 5: Q = 0.863367891263984
# Action 6: Q = 0.8575935428789428
# Action 7: Q = -0.1
# Action 8: Q = 0.881822941793251
# -------
# State: ((1, 0, 1), (0, -1, 0), (1, -1, 0))
# Action 0: Q = -0.1
# Action 1: Q = 0.9999999999999996
# Action 2: Q = 0
# Action 3: Q = 0.8865771779636947
# Action 4: Q = 0
# Action 5: Q = 0.8223244631366002
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0.1982432173004535
# -------
# State: ((1, -1, 1), (0, -1, 0), (1, -1, 0))
# Action 0: Q = 0
# Action 1: Q = -0.19
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 0, 0), (1, 0, 0), (0, 0, 0))
# Action 0: Q = -0.46855900000000006
# Action 1: Q = 0.7063006703790926
# Action 2: Q = 0.6962516091056078
# Action 3: Q = 0
# Action 4: Q = 0.7178638155133104
# Action 5: Q = 0.7226547657104918
# Action 6: Q = 0.7240133455288278
# Action 7: Q = 0.7138393879768512
# Action 8: Q = 0.7356245983081546
# -------
# State: ((-1, 0, 1), (1, 0, 0), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0.5272639213312016
# Action 2: Q = -0.19
# Action 3: Q = -0.1
# Action 4: Q = 0.7881126285420085
# Action 5: Q = 0.47532000369245336
# Action 6: Q = 0.49323904605904934
# Action 7: Q = 0.692629515909338
# Action 8: Q = 0.7554232333106955
# -------
# State: ((-1, 0, 1), (1, 0, 0), (-1, 0, 0))
# Action 0: Q = -0.19
# Action 1: Q = 0.5118947301791481
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.6130298132372902
# Action 5: Q = 0.6056368131315834
# Action 6: Q = -0.19
# Action 7: Q = 0.3214957615436101
# Action 8: Q = 0.1301950019195951
# -------
# State: ((-1, 0, 1), (1, 0, 0), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0.0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.0
# Action 5: Q = 0.0
# Action 6: Q = 0
# Action 7: Q = 0.0
# Action 8: Q = -0.19
# -------
# State: ((-1, -1, 1), (1, 0, 0), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = -0.19
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.0
# Action 5: Q = -0.7516444767177672
# Action 6: Q = 0
# Action 7: Q = 0.0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 1), (1, 1, 0), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0.0
# Action 6: Q = 0
# Action 7: Q = 0.0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 1), (1, 1, -1), (-1, 0, 1))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.1
# Action 6: Q = 0
# Action 7: Q = 0.0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 1), (1, 1, -1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = -0.1
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = -0.19
# Action 8: Q = -0.271
# -------
# State: ((0, 0, 0), (1, 0, 0), (0, 0, -1))
# Action 0: Q = 0.6901410724704273
# Action 1: Q = 0.724433352431855
# Action 2: Q = 0.7808347079809783
# Action 3: Q = 0
# Action 4: Q = 0.6950626221668139
# Action 5: Q = 0.7288691563604319
# Action 6: Q = 0.7327495559325047
# Action 7: Q = 0.7289214216990364
# Action 8: Q = -0.46855900000000006
# -------
# State: ((0, 0, 0), (1, 1, 0), (0, 0, -1))
# Action 0: Q = 0.6316037698965085
# Action 1: Q = 0.6775542687767897
# Action 2: Q = 0.7511355659090643
# Action 3: Q = -0.271
# Action 4: Q = -0.271
# Action 5: Q = 0.7743630656201494
# Action 6: Q = 0.7501845069782036
# Action 7: Q = 0.7661128632696462
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (1, 1, 0), (-1, 0, -1))
# Action 0: Q = 0.8804387268105728
# Action 1: Q = 0.7679053336220648
# Action 2: Q = 0.8914365087237979
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.812302545251753
# Action 6: Q = -0.1
# Action 7: Q = 0.47218434698426826
# Action 8: Q = -0.1
# -------
# State: ((0, 0, 0), (1, 1, 1), (-1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.20791000000000004
# Action 4: Q = 0
# Action 5: Q = 0.1
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (0, 0, 0), (0, 0, 0))
# Action 0: Q = -0.8332281830033343
# Action 1: Q = 0
# Action 2: Q = 0.7030785303123825
# Action 3: Q = 0.7072811278443661
# Action 4: Q = 0.7162891964187681
# Action 5: Q = 0.7101415885694182
# Action 6: Q = 0.6857808700318206
# Action 7: Q = 0.6995462614178883
# Action 8: Q = 0.7154000744119311
# -------
# State: ((-1, 1, 0), (0, 1, 0), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = -0.19
# Action 2: Q = 0.5659151844158943
# Action 3: Q = 0.7413756914155616
# Action 4: Q = -0.34390000000000004
# Action 5: Q = 0.43359697257809593
# Action 6: Q = 0.8049056311896975
# Action 7: Q = 0.6479063217362023
# Action 8: Q = 0.6955561076756669
# -------
# State: ((-1, 1, 0), (0, 1, 0), (0, 0, -1))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = 0.6194199614353474
# Action 3: Q = 0.5963855533633545
# Action 4: Q = 0
# Action 5: Q = 0.5416582840418134
# Action 6: Q = 0.7952760171520539
# Action 7: Q = -0.04170738259171826
# Action 8: Q = -0.1
# -------
# State: ((-1, 1, 0), (0, 1, 1), (0, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.0
# Action 3: Q = 0.2728861015847703
# Action 4: Q = 0
# Action 5: Q = -0.19
# Action 6: Q = 0.7200822013916782
# Action 7: Q = 0.30125953074676115
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (0, 1, 1), (0, -1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.16493792638812488
# Action 3: Q = -0.5437985170321593
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.9847714510445073
# Action 7: Q = -0.1
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (0, 1, 1), (1, -1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.0
# Action 3: Q = 0.0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, -1), (0, 1, 1), (1, -1, -1))
# Action 0: Q = -0.19
# Action 1: Q = 0
# Action 2: Q = -0.1
# Action 3: Q = -0.25761019971937227
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, -1), (1, 1, 1), (1, -1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.2978119
# Action 4: Q = 0.10900000000000001
# Action 5: Q = 0.12680307100000002
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 1), (0, 0, 0), (0, 0, 0))
# Action 0: Q = 0.6423905828481283
# Action 1: Q = 0.5917866850000912
# Action 2: Q = -0.9999939236039033
# Action 3: Q = 0.6748281317372847
# Action 4: Q = 0.6748912701687836
# Action 5: Q = 0.60206749145458
# Action 6: Q = 0.6401479158445241
# Action 7: Q = 0.6845479306343176
# Action 8: Q = 0.6745986866146526
# -------
# State: ((0, 0, 1), (0, 0, 0), (0, -1, 0))
# Action 0: Q = 0.6996789345711234
# Action 1: Q = 0.6947788689109151
# Action 2: Q = 0
# Action 3: Q = 0.7613962200508878
# Action 4: Q = 0.7392432193397994
# Action 5: Q = 0.7336070356359615
# Action 6: Q = 0.6948771096182668
# Action 7: Q = -0.7458134171671
# Action 8: Q = 0.6714939079078996
# -------
# State: ((0, 0, 1), (1, 0, 0), (0, -1, 0))
# Action 0: Q = 0.6793877936496472
# Action 1: Q = 0.8091909802351974
# Action 2: Q = -0.1
# Action 3: Q = -0.271
# Action 4: Q = 0.847613295291169
# Action 5: Q = 0.6766708749485996
# Action 6: Q = 0.8054695366616847
# Action 7: Q = 0
# Action 8: Q = 0.7908859340390066
# -------
# State: ((0, -1, 1), (1, 0, 0), (0, -1, 0))
# Action 0: Q = 0.8818525337533912
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.6730937519934164
# Action 5: Q = 0.8912296795859472
# Action 6: Q = 0.8848084627711112
# Action 7: Q = 0
# Action 8: Q = 0.8899670922989822
# -------
# State: ((0, -1, 1), (1, 1, 0), (0, -1, 0))
# Action 0: Q = 0.0
# Action 1: Q = 0
# Action 2: Q = -0.1
# Action 3: Q = -0.1
# Action 4: Q = -0.1
# Action 5: Q = 0.4529742711181227
# Action 6: Q = 0.7695455462204077
# Action 7: Q = 0
# Action 8: Q = 0.25482033173883306
# -------
# State: ((-1, -1, 1), (1, 1, 0), (0, -1, 0))
# Action 0: Q = -0.19
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.8962993497841618
# Action 6: Q = -0.8648576009049224
# Action 7: Q = 0
# Action 8: Q = 0.0
# -------
# State: ((-1, -1, 1), (1, 1, 1), (0, -1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0.1
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (-1, 0, 0), (0, 1, 0))
# Action 0: Q = 0.7278871213764326
# Action 1: Q = 0.7323951616586393
# Action 2: Q = 0.7376514813186412
# Action 3: Q = -0.8332281830033343
# Action 4: Q = 0.7289432279104319
# Action 5: Q = 0.757541188430497
# Action 6: Q = 0.7291162753730054
# Action 7: Q = 0
# Action 8: Q = 0.7271253226289857
# -------
# State: ((0, 0, 0), (-1, 0, 1), (0, 1, 0))
# Action 0: Q = 0.8095281922828976
# Action 1: Q = 0.6852030515864648
# Action 2: Q = 0.6860770272017059
# Action 3: Q = 0
# Action 4: Q = 0.7049211835658257
# Action 5: Q = -0.271
# Action 6: Q = 0.7665972766947263
# Action 7: Q = -0.271
# Action 8: Q = 0.6511111924244924
# -------
# State: ((-1, 0, 0), (-1, 0, 1), (0, 1, 0))
# Action 0: Q = -0.19
# Action 1: Q = 0.899513409811203
# Action 2: Q = 0.8995477817607118
# Action 3: Q = 0
# Action 4: Q = 0.8920885549004526
# Action 5: Q = 0
# Action 6: Q = 0.6575968581581354
# Action 7: Q = 0
# Action 8: Q = 0.8974396435752117
# -------
# State: ((-1, 0, 0), (-1, 0, 1), (1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0.7404526914142903
# Action 2: Q = 0.660447665289027
# Action 3: Q = 0
# Action 4: Q = 0.6349180138976088
# Action 5: Q = -0.1
# Action 6: Q = -0.1
# Action 7: Q = -0.1
# Action 8: Q = 0.5081312213344132
# -------
# State: ((-1, 0, -1), (-1, 0, 1), (1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0.7482591939329116
# Action 2: Q = -0.1
# Action 3: Q = -0.1
# Action 4: Q = 0.5656355276886189
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = -0.8579046859620567
# -------
# State: ((-1, 1, -1), (-1, 0, 1), (1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.17115333580967554
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = -0.1
# Action 8: Q = 0.1847146747105433
# -------
# State: ((-1, 1, -1), (-1, 0, 1), (1, 1, -1))
# Action 0: Q = -0.19
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.6792415520857281
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = -0.19
# -------
# State: ((-1, 1, -1), (-1, 1, 1), (1, 1, -1))
# Action 0: Q = 0
# Action 1: Q = 0.33629581000000003
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.3975756229
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.24983961606100002
# Action 8: Q = 0
# -------
# State: ((-1, 0, 0), (0, 0, 0), (0, 0, 1))
# Action 0: Q = -0.8499053647030009
# Action 1: Q = 0.725291984264803
# Action 2: Q = 0.7105690081111815
# Action 3: Q = 0.7260868044767524
# Action 4: Q = 0.718512122445879
# Action 5: Q = 0.7061773433114151
# Action 6: Q = 0.7090384019560477
# Action 7: Q = 0.7137346251138685
# Action 8: Q = 0
# -------
# State: ((-1, 0, 0), (0, 0, 1), (0, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0.7315613738337572
# Action 2: Q = 0.7059024448704536
# Action 3: Q = 0.7817160721995632
# Action 4: Q = 0.7059094603212237
# Action 5: Q = -0.271
# Action 6: Q = 0.8080332338178287
# Action 7: Q = 0.6225710712573729
# Action 8: Q = -0.271
# -------
# State: ((-1, 0, 0), (0, 0, 1), (0, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0.5315725553150786
# Action 2: Q = -0.8730976013997783
# Action 3: Q = 0.7041733302605038
# Action 4: Q = 0.5387691171198137
# Action 5: Q = 0
# Action 6: Q = 0.46411530679627183
# Action 7: Q = -0.19
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (0, 0, 1), (0, -1, 1))
# Action 0: Q = 0
# Action 1: Q = -0.19
# Action 2: Q = 0.031913216385519305
# Action 3: Q = 0.7184174597310133
# Action 4: Q = 0.03388381000999484
# Action 5: Q = 0
# Action 6: Q = 0.13977258752816754
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (-1, 0, 1), (0, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = -0.7945288320608417
# Action 3: Q = -0.1
# Action 4: Q = 0.6023581146096019
# Action 5: Q = 0
# Action 6: Q = 0.739634785575655
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (-1, 0, 1), (1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.0
# Action 3: Q = 0
# Action 4: Q = 0.0
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = -0.1
# -------
# State: ((-1, 1, -1), (-1, 0, 1), (1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = -0.19
# Action 3: Q = 0
# Action 4: Q = 0.0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, -1), (-1, 1, 1), (1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = -0.19
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = -0.19
# Action 5: Q = -0.19
# Action 6: Q = -0.19
# Action 7: Q = 0
# Action 8: Q = -0.271
# -------
# State: ((0, 0, -1), (0, 1, 0), (1, 0, 0))
# Action 0: Q = 0.7894793546654456
# Action 1: Q = 0.8187505800175261
# Action 2: Q = 0
# Action 3: Q = 0.6264982677799033
# Action 4: Q = -0.34390000000000004
# Action 5: Q = 0.8099999999998398
# Action 6: Q = -0.34390000000000004
# Action 7: Q = 0.5337158938962593
# Action 8: Q = 0.759870812540362
# -------
# State: ((-1, 0, -1), (0, 1, 0), (1, 0, 0))
# Action 0: Q = -0.1
# Action 1: Q = 0.6054142963363671
# Action 2: Q = 0
# Action 3: Q = 0.8808406930178135
# Action 4: Q = 0
# Action 5: Q = 0.8730060994904136
# Action 6: Q = 0
# Action 7: Q = 0.8594546663401282
# Action 8: Q = 0.8760775815144595
# -------
# State: ((-1, 0, -1), (0, 1, 0), (1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0.9999999999999996
# Action 2: Q = 0
# Action 3: Q = 0.10718721104865597
# Action 4: Q = -0.1
# Action 5: Q = 0.7071988778864279
# Action 6: Q = 0
# Action 7: Q = -0.1
# Action 8: Q = 0.8922955103927441
# -------
# State: ((-1, -1, -1), (0, 1, 0), (1, 1, 0))
# Action 0: Q = -0.1
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 1, 0), (0, -1, 1), (0, 0, 0))
# Action 0: Q = 0.7808412547789298
# Action 1: Q = -0.40951000000000004
# Action 2: Q = 0.7618745994772697
# Action 3: Q = 0.7015354216776745
# Action 4: Q = 0
# Action 5: Q = -0.271
# Action 6: Q = 0.8033755395318948
# Action 7: Q = 0.7177235323887808
# Action 8: Q = 0.759010460927069
# -------
# State: ((0, 1, 0), (0, -1, 1), (0, -1, 0))
# Action 0: Q = 0.6931539525971149
# Action 1: Q = 0
# Action 2: Q = 0.7466849391697932
# Action 3: Q = 0.5061447275736521
# Action 4: Q = -0.19
# Action 5: Q = 0
# Action 6: Q = 0.6733070934031232
# Action 7: Q = -0.271
# Action 8: Q = 0.8021896060424265
# -------
# State: ((0, 1, 0), (1, -1, 1), (0, -1, 0))
# Action 0: Q = 0.6028720455437627
# Action 1: Q = 0
# Action 2: Q = 0.5542880885984096
# Action 3: Q = -0.1
# Action 4: Q = 0
# Action 5: Q = -0.19
# Action 6: Q = 0.8764570211136177
# Action 7: Q = 0
# Action 8: Q = 0.8431266298702423
# -------
# State: ((0, 1, 0), (1, -1, 1), (-1, -1, 0))
# Action 0: Q = 0.8032213866100784
# Action 1: Q = 0
# Action 2: Q = 0.9458293453922962
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0.9715090006768777
# -------
# State: ((0, 1, 1), (1, -1, 1), (-1, -1, 0))
# Action 0: Q = 0.4389099435453603
# Action 1: Q = 0
# Action 2: Q = -0.1
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.1
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.999999999998859
# -------
# State: ((0, 1, 1), (1, -1, 1), (-1, -1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = -0.1
# Action 8: Q = -0.1
# -------
# State: ((0, 0, 0), (0, 0, 1), (0, -1, 0))
# Action 0: Q = 0.7251271849861896
# Action 1: Q = 0.7610558221967889
# Action 2: Q = 0.745571885688236
# Action 3: Q = 0.7581390105104103
# Action 4: Q = 0.7110477271090391
# Action 5: Q = 0
# Action 6: Q = 0.72782347040683
# Action 7: Q = -0.8499053647030009
# Action 8: Q = 0.7560514582533209
# -------
# State: ((0, 0, 1), (0, 0, 1), (0, -1, 0))
# Action 0: Q = 0.6768847301552261
# Action 1: Q = 0.8099797876992652
# Action 2: Q = -0.34390000000000004
# Action 3: Q = 0.6408465225546048
# Action 4: Q = 0.809631936196189
# Action 5: Q = 0
# Action 6: Q = 0.7389599981732126
# Action 7: Q = 0
# Action 8: Q = 0.7808203454109941
# -------
# State: ((0, 0, 1), (0, 0, 1), (-1, -1, 0))
# Action 0: Q = 0.8194100501433705
# Action 1: Q = 0.8189791712811676
# Action 2: Q = 0
# Action 3: Q = 0.8201238528468037
# Action 4: Q = 0.8172872347768833
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0.2335218802264938
# -------
# State: ((0, 0, 1), (0, 0, 1), (-1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.10900000000000001
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.1
# -------
# State: ((0, 0, 0), (0, 0, -1), (0, 1, 0))
# Action 0: Q = 0.7023338923772334
# Action 1: Q = 0.700641840331403
# Action 2: Q = 0.6916254565302101
# Action 3: Q = 0.7108997976750719
# Action 4: Q = 0.7157503600224937
# Action 5: Q = -0.8649148282327008
# Action 6: Q = 0.7089652760923987
# Action 7: Q = 0
# Action 8: Q = 0.6874606780007514
# -------
# State: ((0, 0, 0), (0, 0, -1), (1, 1, 0))
# Action 0: Q = 0.6734970780720342
# Action 1: Q = 0.6772834696840314
# Action 2: Q = 0.7237695731813729
# Action 3: Q = 0.7890081263657119
# Action 4: Q = 0.7968348452524067
# Action 5: Q = 0
# Action 6: Q = -0.271
# Action 7: Q = -0.34390000000000004
# Action 8: Q = 0.7764430943053087
# -------
# State: ((0, 0, 0), (0, -1, -1), (1, 1, 0))
# Action 0: Q = 0.8753627270727552
# Action 1: Q = 0.8782905766542449
# Action 2: Q = 0.8816607480157419
# Action 3: Q = 0.7696935590613497
# Action 4: Q = -0.19
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = -0.820045531414088
# -------
# State: ((0, 0, 0), (0, -1, -1), (1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.10900000000000001
# Action 7: Q = 0.1179829
# Action 8: Q = 0.19981000000000002
# -------
# State: ((0, 0, 0), (0, 0, 0), (-1, 1, 0))
# Action 0: Q = 0.7289931183081285
# Action 1: Q = 0.7181954988368965
# Action 2: Q = 0.7449670523974564
# Action 3: Q = 0.7343382083310738
# Action 4: Q = 0.7193244310581108
# Action 5: Q = 0.7364856866218588
# Action 6: Q = -0.68618940391
# Action 7: Q = 0
# Action 8: Q = 0.728667034520186
# -------
# State: ((0, 0, 1), (0, 0, 0), (-1, 1, 0))
# Action 0: Q = 0.72661957638605
# Action 1: Q = 0.5599792226516525
# Action 2: Q = -0.271
# Action 3: Q = 0.8114223821475058
# Action 4: Q = 0.613735995940173
# Action 5: Q = 0.6930747935556542
# Action 6: Q = 0
# Action 7: Q = -0.1
# Action 8: Q = 0.5679374983266476
# -------
# State: ((-1, 0, 1), (0, 0, 0), (-1, 1, 0))
# Action 0: Q = -0.1
# Action 1: Q = 0.7108014519597345
# Action 2: Q = 0
# Action 3: Q = 0.7194185988675664
# Action 4: Q = 0.6661106653550516
# Action 5: Q = 0.810458448202694
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.6629713827132078
# -------
# State: ((-1, 0, 1), (0, 0, 1), (-1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0.3722243111282926
# Action 2: Q = 0
# Action 3: Q = 0.9999999999999996
# Action 4: Q = 0.7241822170535417
# Action 5: Q = -0.1
# Action 6: Q = 0
# Action 7: Q = -0.1
# Action 8: Q = 0.7706434415832747
# -------
# State: ((-1, 0, 1), (0, -1, 1), (-1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0.6035997249725586
# Action 2: Q = 0
# Action 3: Q = 0.9879986050021391
# Action 4: Q = -0.19
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = -0.3071035836488981
# -------
# State: ((-1, 0, 1), (1, -1, 1), (-1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0.12318632274814748
# Action 2: Q = 0
# Action 3: Q = -0.271
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.9999999995371164
# -------
# State: ((-1, -1, 1), (1, -1, 1), (-1, 1, 0))
# Action 0: Q = -0.1
# Action 1: Q = -0.1
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = -0.1621301625827091
# -------
# State: ((-1, -1, 1), (1, -1, 1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.10900000000000001
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0.20871190000000003
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.30669623029000004
# -------
# State: ((1, 0, 0), (0, -1, 1), (0, 0, 0))
# Action 0: Q = -0.1
# Action 1: Q = 0.5245034417997286
# Action 2: Q = 0.802460635448633
# Action 3: Q = 0.6036221317515303
# Action 4: Q = 0
# Action 5: Q = -0.1
# Action 6: Q = 0.7361405402926884
# Action 7: Q = 0.7704163472338663
# Action 8: Q = 0.7136528801917233
# -------
# State: ((1, -1, 0), (0, -1, 1), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = -0.19
# Action 2: Q = 0.40128873182830355
# Action 3: Q = 0.5276806141104031
# Action 4: Q = -0.19
# Action 5: Q = 0
# Action 6: Q = 0.5344042901090346
# Action 7: Q = 0.49851979248976114
# Action 8: Q = 0.5558267480822221
# -------
# State: ((1, -1, 0), (0, -1, 1), (0, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.6530569904519625
# Action 3: Q = 0.00014812532219344324
# Action 4: Q = 0
# Action 5: Q = -0.19
# Action 6: Q = 0
# Action 7: Q = -0.1
# Action 8: Q = 0.004274746535533907
# -------
# State: ((1, -1, 0), (0, -1, 1), (0, 1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.7492486655141758
# Action 3: Q = 0.2227219110368684
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.23931348327645832
# Action 7: Q = 0
# Action 8: Q = -0.19
# -------
# State: ((1, -1, 0), (1, -1, 1), (0, 1, -1))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = 0.3376187829111336
# Action 3: Q = -0.1
# Action 4: Q = 0
# Action 5: Q = -0.1
# Action 6: Q = 0.5052136685463764
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, 0), (1, -1, 1), (-1, 1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.6839988630029206
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0
# Action 6: Q = -0.19
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, -1, 0), (0, 0, 1), (0, 0, 0))
# Action 0: Q = 0.696775170554194
# Action 1: Q = -0.7941088679053511
# Action 2: Q = 0.80653242302619
# Action 3: Q = 0.722884632670637
# Action 4: Q = 0.74894805505585
# Action 5: Q = 0
# Action 6: Q = 0.7121185096718621
# Action 7: Q = 0.6345252549006377
# Action 8: Q = 0.7751724008312547
# -------
# State: ((0, -1, 0), (0, 0, 1), (0, 0, 1))
# Action 0: Q = 0.7334766711474978
# Action 1: Q = 0
# Action 2: Q = 0.8499251962437426
# Action 3: Q = 0.5032833417227759
# Action 4: Q = 0.74083397352791
# Action 5: Q = -0.19
# Action 6: Q = 0.6561760406530248
# Action 7: Q = 0.8042360795346651
# Action 8: Q = -0.271
# -------
# State: ((-1, -1, 0), (0, 0, 1), (0, 0, 1))
# Action 0: Q = -0.271
# Action 1: Q = 0
# Action 2: Q = 0.1806117679116176
# Action 3: Q = 0.7643101094925734
# Action 4: Q = 0.7463448544768492
# Action 5: Q = 0
# Action 6: Q = 0.7451429191752208
# Action 7: Q = 0.8215984666498853
# Action 8: Q = 0
# -------
# State: ((-1, -1, 0), (0, 0, 1), (0, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.9999999993650429
# Action 3: Q = 0.22761858679606659
# Action 4: Q = 0.06879721788508308
# Action 5: Q = 0
# Action 6: Q = 0.2624775333259998
# Action 7: Q = -0.271
# Action 8: Q = 0
# -------
# State: ((-1, -1, 0), (0, 0, 1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = -0.1
# Action 2: Q = -0.8133890657382581
# Action 3: Q = 0.9883760749511937
# Action 4: Q = 0.5725515627391734
# Action 5: Q = 0
# Action 6: Q = -0.1
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 0), (1, 0, 1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.9999999998206694
# Action 3: Q = -0.19
# Action 4: Q = 0.08258661342327922
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 0), (1, -1, 1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = -0.022946994121468195
# Action 3: Q = 0
# Action 4: Q = -0.1
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, 0), (0, -1, 1), (0, -1, 0))
# Action 0: Q = -0.1
# Action 1: Q = 0
# Action 2: Q = 0.8298993466127134
# Action 3: Q = 0.3427868942899339
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.884960305335833
# Action 7: Q = 0
# Action 8: Q = 0.8277461523751498
# -------
# State: ((1, 1, 0), (0, -1, 1), (0, -1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.09691088292839897
# Action 3: Q = 0.10404166970872104
# Action 4: Q = 0
# ...
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, 0), (-1, -1, -1), (0, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 0, -1), (-1, 0, 1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, 0), (-1, -1, -1), (-1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, 1), (0, -1, 1), (-1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.5610626172276342
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 1), (0, 0, 1), (-1, 1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.15050250367163864
# Action 4: Q = 0.40030995205504305
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, -1, 0), (-1, 1, 0), (-1, 0, 1))
# Action 0: Q = -0.9656631617970749
# Action 1: Q = 0
# Action 2: Q = 0.09470963585389329
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0.06262497301374358
# Action 6: Q = 0
# Action 7: Q = 0.32176126275520917
# Action 8: Q = 0
# -------
# State: ((1, -1, 0), (1, -1, 0), (-1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.37389582767576157
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0.19137932039419434
# Action 6: Q = 0
# Action 7: Q = 0.24970296171019504
# Action 8: Q = 0.31433780459966887
# -------
# State: ((-1, 1, 0), (0, 1, -1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, 0), (1, 0, -1), (0, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.0985603445219988
# Action 3: Q = 0
# Action 4: Q = 0.4736704663533898
# Action 5: Q = 0
# Action 6: Q = -0.6513215599000001
# Action 7: Q = 0.5300225143384958
# Action 8: Q = 0
# -------
# State: ((1, -1, -1), (0, 0, -1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.13501668158563457
# Action 4: Q = -0.911370618803475
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, 0), (0, 0, -1), (-1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.8381467327936367
# Action 3: Q = 0.13588654687808016
# Action 4: Q = 0.19807189962945274
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.010520253346394379
# -------
# State: ((0, -1, -1), (0, 1, -1), (0, 1, 0))
# Action 0: Q = 0.5420244542030684
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.4192302999352968
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.5473880241560195
# Action 7: Q = 0
# Action 8: Q = 0.45167792106504673
# -------
# State: ((1, 1, -1), (0, -1, -1), (1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.9999999999967276
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.45482571141267697
# Action 8: Q = 0
# -------
# State: ((0, 1, -1), (1, -1, 1), (-1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, 0), (0, 1, -1), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 1), (0, -1, 1), (-1, 0, -1))
# Action 0: Q = 0.8929257895378281
# Action 1: Q = 0.8868994133077801
# Action 2: Q = 0
# Action 3: Q = 0.848622394709585
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.7073905611860755
# Action 8: Q = 0
# -------
# State: ((0, -1, -1), (1, -1, 1), (1, 0, 0))
# Action 0: Q = 0.010000000000000009
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.2759730124540422
# Action 8: Q = 0.7094785716101062
# -------
# State: ((-1, -1, -1), (0, 1, 1), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, -1, 0), (-1, 1, 0), (-1, 1, 0))
# Action 0: Q = 0.0
# Action 1: Q = 0
# Action 2: Q = 0.4315368721193205
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0.5359839173977672
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.425070744635505
# -------
# State: ((0, -1, 1), (0, -1, 1), (0, 0, -1))
# Action 0: Q = 0.06283116646981445
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.20344099784607905
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.22924683067841523
# Action 7: Q = 0.09951641318166762
# Action 8: Q = 0
# -------
# State: ((1, -1, -1), (1, -1, 1), (1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 0, -1), (-1, 0, -1), (1, 1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, -1, -1), (1, 1, 0), (-1, 0, 0))
# Action 0: Q = 0.15385409286795812
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = -0.717570463519
# Action 6: Q = 0
# Action 7: Q = 0.5503120632028534
# Action 8: Q = 0.06154071656664857
# -------
# State: ((-1, -1, 1), (-1, 0, 1), (-1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 1, -1), (1, 0, -1), (0, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 1), (-1, -1, -1), (0, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, 1), (-1, 0, 0), (-1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.20716289012590278
# Action 5: Q = 0.21926863440974154
# Action 6: Q = 0
# Action 7: Q = 0.12915423781107815
# Action 8: Q = 0.026453424487147024
# -------
# State: ((0, 1, 0), (-1, -1, -1), (1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, -1), (-1, -1, -1), (0, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, 1), (-1, -1, -1), (1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, 1), (-1, 0, -1), (-1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 0, -1), (-1, 1, -1), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0.6698142082307237
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.6971178929927795
# Action 7: Q = 0.8931351292901226
# Action 8: Q = -0.9999999999999996
# -------
# State: ((-1, 1, 0), (1, -1, 1), (-1, -1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.6460579657964369
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.34718335436761494
# -------
# State: ((1, 0, 0), (1, -1, -1), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0.8126073190259897
# Action 2: Q = 0.2061866806756346
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.8355467386507696
# Action 8: Q = 0
# -------
# State: ((1, 0, -1), (1, 1, -1), (-1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, -1), (-1, -1, 1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 1), (-1, -1, 0), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, -1), (0, -1, -1), (1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 0, 1), (-1, -1, -1), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (-1, 0, -1), (0, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.8515416006349082
# Action 3: Q = 0
# Action 4: Q = 0.4360190534282879
# Action 5: Q = 0
# Action 6: Q = 0.8740038889483239
# Action 7: Q = 0.8718992802204125
# Action 8: Q = 0
# -------
# State: ((0, 1, -1), (0, 1, -1), (-1, 1, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, -1), (-1, 0, -1), (1, 0, 1))
# Action 0: Q = 0.8236055967700668
# Action 1: Q = 0.7393883173053547
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = -0.9999999995371164
# Action 8: Q = 0
# -------
# State: ((-1, 0, -1), (-1, 1, 1), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, -1, 1), (-1, -1, -1), (1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 0, 0), (0, -1, 0), (1, -1, 1))
# Action 0: Q = 0
# Action 1: Q = 0.05388493068781206
# Action 2: Q = 0.49313132995910824
# Action 3: Q = 0.4377294833167913
# Action 4: Q = 0
# Action 5: Q = 0.6214382573798246
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, 1), (-1, -1, -1), (0, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (1, 0, -1), (-1, 1, 1))
# Action 0: Q = 0.08879703973221587
# Action 1: Q = 0
# Action 2: Q = 0.08391927292997116
# Action 3: Q = 0
# Action 4: Q = 0.5950555188057832
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (-1, 1, -1), (-1, 0, 1))
# Action 0: Q = -0.9999999999999996
# Action 1: Q = 0.8986114459446946
# Action 2: Q = 0.8765649129111192
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.8915110475911886
# Action 8: Q = 0
# -------
# State: ((1, 0, -1), (1, -1, -1), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, -1, 0), (1, -1, 0), (-1, 0, 1))
# Action 0: Q = 0.7101994997569914
# Action 1: Q = 0
# Action 2: Q = 0.5949210366024202
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0.7278087802700592
# Action 6: Q = 0
# Action 7: Q = 0.42514736334890146
# Action 8: Q = 0
# -------
# State: ((1, -1, -1), (0, 0, 1), (-1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0.24849749381005634
# Action 4: Q = 0.0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.3825420050083199
# Action 8: Q = 0.3220033664460593
# -------
# State: ((1, -1, -1), (0, 1, -1), (1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, -1), (-1, -1, -1), (0, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 1), (-1, 0, -1), (0, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.23744118556381352
# Action 5: Q = 0
# Action 6: Q = 0.6530440376866187
# Action 7: Q = 0.7447235495680479
# Action 8: Q = 0.7633854109517587
# -------
# State: ((1, -1, 0), (-1, 0, -1), (1, 0, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0.6912952887938995
# Action 3: Q = 0
# Action 4: Q = 0.01387824855011174
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.8680448548310233
# Action 8: Q = 0.031454871540226206
# -------
# State: ((1, 1, -1), (-1, 0, -1), (0, 1, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, -1), (-1, 1, 0), (-1, 0, 1))
# Action 0: Q = -0.9866972053527088
# Action 1: Q = 0.08691587052584515
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0.3744316581111773
# Action 6: Q = 0
# Action 7: Q = 0.2181837369763422
# Action 8: Q = 0
# -------
# State: ((0, 1, -1), (-1, 0, 0), (-1, 1, 0))
# Action 0: Q = 0.7314569351627066
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = -0.9903022627021246
# Action 5: Q = 0.7662607522003678
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0.8567061578592885
# -------
# State: ((0, 1, -1), (-1, 1, 0), (-1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, 1, -1), (0, 1, -1), (-1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((0, 0, 0), (1, -1, -1), (-1, 0, 1))
# Action 0: Q = 0.5771450997593295
# Action 1: Q = 0.3751689271701054
# Action 2: Q = 0.29420999464977327
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0.46955975295518243
# Action 8: Q = 0
# -------
# State: ((0, 1, 0), (-1, 0, 0), (-1, 1, -1))
# Action 0: Q = 0.17939247198837843
# Action 1: Q = 0
# Action 2: Q = 0.2568112565338314
# Action 3: Q = 0
# Action 4: Q = -0.9980033218889841
# Action 5: Q = 0.8300788390384319
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 0), (-1, 1, 1), (-1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, -1), (1, -1, 0), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, -1, 1), (1, -1, 0), (1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 0, 1), (-1, 1, 1), (-1, 0, -1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 0, 1), (-1, 0, -1), (0, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0.8849828479188502
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0.7396397321940221
# Action 5: Q = 0
# Action 6: Q = 0.7457201493775979
# Action 7: Q = 0.8947668422503702
# Action 8: Q = 0
# -------
# State: ((0, -1, -1), (1, -1, 1), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((1, -1, -1), (-1, 1, 1), (0, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0.0
# Action 7: Q = 0
# Action 8: Q = 0.0
# -------
# State: ((1, -1, -1), (0, -1, 1), (-1, 1, 0))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------
# State: ((-1, 1, 1), (-1, 0, -1), (-1, 0, 1))
# Action 0: Q = 0
# Action 1: Q = 0
# Action 2: Q = 0
# Action 3: Q = 0
# Action 4: Q = 0
# Action 5: Q = 0
# Action 6: Q = 0
# Action 7: Q = 0
# Action 8: Q = 0
# -------

# %%
play_game(agent)
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
